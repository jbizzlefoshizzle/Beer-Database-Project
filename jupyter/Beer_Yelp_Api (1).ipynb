# %%
import requests
import json
from pprint import pprint
api_key = "qQKFH7ON5ZMnxC1FlVf-uR4-lqBsw1Izi7G7bFaQoZZzs10TDoRkSMzZCF4fjhxmdv5ZyZ2hZTnM8f8HH5cLWApaL3Fn7C1Wp82PEkex4QsBO5LwZVsXRv__IjfvXHYx"
url = "https://api.yelp.com/v3/businesses/search"
import pandas as pd

# %%
headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

# headers={'Authorization': api_key}

# %%
print(headers)
# Out:
# {'Authorization': 'Bearer qQKFH7ON5ZMnxC1FlVf-uR4-lqBsw1Izi7G7bFaQoZZzs10TDoRkSMzZCF4fjhxmdv5ZyZ2hZTnM8f8HH5cLWApaL3Fn7C1Wp82PEkex4QsBO5LwZVsXRv__IjfvXHYx'}

# %%
paramDict = {"term": "breweries", "location": "San Diego", "radius": 39000}

# %%
response = requests.get(url, params=paramDict, headers=headers)

# %%
data = response.json()

# %%
pprint(data)
# Out:
# {'businesses': [{'alias': 'societe-brewing-company-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.833889,
#                                  'longitude': -117.146375},
#                  'display_phone': '(858) 598-5409',
#                  'distance': 4870.482140841581,
#                  'id': 'i0z5qviFAZe5knHFwSIYSg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3kMzqyZcEEt6d0hliKjbQA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8262 Clairemont Mesa Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['8262 Clairemont Mesa Blvd',
#                                                   'San Diego, CA 92111'],
#                               'state': 'CA',
#                               'zip_code': '92111'},
#                  'name': 'Societe Brewing Company',
#                  'phone': '+18585985409',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 607,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/societe-brewing-company-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'alesmith-brewing-company-san-diego-3',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.8873241,
#                                  'longitude': -117.1493986},
#                  'display_phone': '(858) 549-9888',
#                  'distance': 10767.519024622454,
#                  'id': 'KyIfHTUpO4cOD-6VfB8oHA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6rvZzm8Eho4dwtpgruYZuQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9990 AleSmith Ct',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['9990 AleSmith Ct',
#                                                   'San Diego, CA 92126'],
#                               'state': 'CA',
#                               'zip_code': '92126'},
#                  'name': 'AleSmith Brewing Company',
#                  'phone': '+18585499888',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 418,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alesmith-brewing-company-san-diego-3?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'pure-project-san-diego-2',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.8873375,
#                                  'longitude': -117.1555986},
#                  'display_phone': '(858) 252-6143',
#                  'distance': 10685.347964342614,
#                  'id': 'UDeOxreWcpk4QofT-wSbDg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tRymvtKbbWF5Tnhdbbp3RA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9030 Kenamar Dr',
#                               'address2': 'Ste 308',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['9030 Kenamar Dr',
#                                                   'Ste 308',
#                                                   'San Diego, CA 92121'],
#                               'state': 'CA',
#                               'zip_code': '92121'},
#                  'name': 'Pure Project',
#                  'phone': '+18582526143',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 661,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pure-project-san-diego-2?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'the-original-40-brewing-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.74824, 'longitude': -117.12662},
#                  'display_phone': '(619) 255-7380',
#                  'distance': 5355.917429636894,
#                  'id': 'YBNWxaRsIe_xkz0hQB1Sgw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UwXAuCaCpGKED8Kmqz-BdQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3117 University Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['3117 University Ave',
#                                                   'San Diego, CA 92104'],
#                               'state': 'CA',
#                               'zip_code': '92104'},
#                  'name': 'The Original 40 Brewing',
#                  'phone': '+16192557380',
#                  'rating': 4.5,
#                  'review_count': 58,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-original-40-brewing-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'belching-beaver-brewery-north-park-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.7545205383526,
#                                  'longitude': -117.13002965232},
#                  'display_phone': '(619) 282-1062',
#                  'distance': 4596.215823790204,
#                  'id': '49qKGDjD06s2J76xslT1pg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JklSUlm9_c1v9QOkAKulqA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4223 30th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['4223 30th St',
#                                                   'San Diego, CA 92104'],
#                               'state': 'CA',
#                               'zip_code': '92104'},
#                  'name': 'Belching Beaver Brewery North Park',
#                  'phone': '+16192821062',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 666,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/belching-beaver-brewery-north-park-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'black-market-brewing-san-diego-san-diego',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#                  'coordinates': {'latitude': 32.76479, 'longitude': -117.06093},
#                  'display_phone': '(619) 866-6033',
#                  'distance': 9126.723188270013,
#                  'id': '3yWHMNMHFznmps4NHR8o9g',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y9VkiQLrXpAQmTUDCLk20w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4800 Art St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['4800 Art St',
#                                                   'San Diego, CA 92115'],
#                               'state': 'CA',
#                               'zip_code': '92115'},
#                  'name': 'Black Market Brewing - San Diego',
#                  'phone': '+16198666033',
#                  'rating': 4.5,
#                  'review_count': 39,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/black-market-brewing-san-diego-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'kilowatt-brewing-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.8333702,
#                                  'longitude': -117.1560135},
#                  'display_phone': '(858) 715-3998',
#                  'distance': 4734.949230739788,
#                  'id': 'b1AS8J9Je6f-Gl6OCXTvUw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JVQQvRqcXx9hIBIUIa9Ilw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7576 Clairemont Mesa Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['7576 Clairemont Mesa Blvd',
#                                                   'San Diego, CA 92111'],
#                               'state': 'CA',
#                               'zip_code': '92111'},
#                  'name': 'Kilowatt Brewing',
#                  'phone': '+18587153998',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 193,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kilowatt-brewing-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'modern-times-beer-san-diego-2',
#                  'categories': [{'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'},
#                                 {'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.754201,
#                                  'longitude': -117.206172011657},
#                  'display_phone': '(619) 546-9694',
#                  'distance': 6330.193801986983,
#                  'id': 'S6TdzC0Naahhk87jVmsRdg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_rBMfj-8JNyFbj_JrW9Sdg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3725 Greenwood St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['3725 Greenwood St',
#                                                   'San Diego, CA 92110'],
#                               'state': 'CA',
#                               'zip_code': '92110'},
#                  'name': 'Modern Times Beer',
#                  'phone': '+16195469694',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 625,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/modern-times-beer-san-diego-2?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'ballast-point-little-italy-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 32.7275213525988,
#                                  'longitude': -117.169813710335},
#                  'display_phone': '(619) 255-7213',
#                  'distance': 7163.2681588508885,
#                  'id': '5fFcXSSZOO6jjVLsSCOssw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z0JmLGPirgtc-pvFHnMoHg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2215 India St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['2215 India St',
#                                                   'San Diego, CA 92101'],
#                               'state': 'CA',
#                               'zip_code': '92101'},
#                  'name': 'Ballast Point Little Italy',
#                  'phone': '+16192557213',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1798,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ballast-point-little-italy-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'half-door-brewing-san-diego',
#                  'categories': [{'alias': 'brewpubs', 'title': 'Brewpubs'}],
#                  'coordinates': {'latitude': 32.710263,
#                                  'longitude': -117.156272},
#                  'display_phone': '(619) 232-9845',
#                  'distance': 8931.99941590621,
#                  'id': '-1YD91bc8-GcLKw2YUPoxQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m1Vy4G82OTWBTH_EIqsXSw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '903 Island Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['903 Island Ave',
#                                                   'San Diego, CA 92101'],
#                               'state': 'CA',
#                               'zip_code': '92101'},
#                  'name': 'Half Door Brewing',
#                  'phone': '+16192329845',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 633,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/half-door-brewing-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'green-flash-brewing-co-san-diego-2',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.9071098,
#                                  'longitude': -117.1777588},
#                  'display_phone': '(858) 622-0085',
#                  'distance': 13146.064265386787,
#                  'id': 'hmyr8qzvwe7iMfYjncYgew',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gJNf7tGTZ1bcreU7yv3RdQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6550 Mira Mesa Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['6550 Mira Mesa Blvd',
#                                                   'San Diego, CA 92121'],
#                               'state': 'CA',
#                               'zip_code': '92121'},
#                  'name': 'Green Flash Brewing Co',
#                  'phone': '+18586220085',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 998,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/green-flash-brewing-co-san-diego-2?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'circle-9-brewing-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.8254665,
#                                  'longitude': -117.160549},
#                  'display_phone': '(858) 634-2537',
#                  'distance': 3959.4972664170323,
#                  'id': '8lhzY6MCy5HqHj8u5oeiLw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wDRnBVrUsNC_E1RGfgvQwA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7292 Opportunity Rd',
#                               'address2': 'Ste C',
#                               'address3': None,
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['7292 Opportunity Rd',
#                                                   'Ste C',
#                                                   'San Diego, CA 92111'],
#                               'state': 'CA',
#                               'zip_code': '92111'},
#                  'name': 'Circle 9 Brewing',
#                  'phone': '+18586342537',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/circle-9-brewing-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'bolt-brewery-la-mesa',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'musicvenues',
#                                  'title': 'Music Venues'}],
#                  'coordinates': {'latitude': 32.7719692578383,
#                                  'longitude': -117.020541742427},
#                  'display_phone': '(619) 303-7837',
#                  'distance': 12654.463892176973,
#                  'id': 'ztPRQdlrLqpqwa4fgRNmfA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bJO5yNf12pFzPkmbf_pTuA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8179 Center St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'La Mesa',
#                               'country': 'US',
#                               'display_address': ['8179 Center St',
#                                                   'La Mesa, CA 91942'],
#                               'state': 'CA',
#                               'zip_code': '91942'},
#                  'name': 'Bolt Brewery',
#                  'phone': '+16193037837',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 238,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bolt-brewery-la-mesa?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'ketch-brewing-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.81315, 'longitude': -117.15545},
#                  'display_phone': '(858) 427-0961',
#                  'distance': 2514.093423389834,
#                  'id': 'dyKUUPkSsGCn2TbNB2iI8Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0PfI9tXfbBhehBsSmAsiKw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7889 Ostrow St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['7889 Ostrow St',
#                                                   'San Diego, CA 92111'],
#                               'state': 'CA',
#                               'zip_code': '92111'},
#                  'name': 'Ketch Brewing',
#                  'phone': '+18584270961',
#                  'rating': 4.5,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ketch-brewing-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'quantum-brewing-san-diego-6',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.83067, 'longitude': -117.13883},
#                  'display_phone': '(858) 254-6481',
#                  'distance': 4716.837124601296,
#                  'id': 'yThPAyBmOvgtXKCO_ilzHg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lta6f4fFqhi80i4vSIIawQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5375 Kearny Villa Rd',
#                               'address2': 'Ste 116',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['5375 Kearny Villa Rd',
#                                                   'Ste 116',
#                                                   'San Diego, CA 92123'],
#                               'state': 'CA',
#                               'zip_code': '92123'},
#                  'name': 'Quantum Brewing',
#                  'phone': '+18582546481',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 192,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/quantum-brewing-san-diego-6?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'mission-brewery-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.70715,
#                                  'longitude': -117.151592},
#                  'display_phone': '(619) 544-0555',
#                  'distance': 9278.728651078824,
#                  'id': 'iklaPUIKWq26LUJv7e681w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h6nmRCLHBeiAUm_ZueGjsg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1441 L St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['1441 L St',
#                                                   'San Diego, CA 92101'],
#                               'state': 'CA',
#                               'zip_code': '92101'},
#                  'name': 'Mission Brewery',
#                  'phone': '+16195440555',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 694,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mission-brewery-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'gravity-heights-san-diego-2',
#                  'categories': [{'alias': 'venues',
#                                  'title': 'Venues & Event Spaces'},
#                                 {'alias': 'brewpubs', 'title': 'Brewpubs'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 32.90016, 'longitude': -117.19086},
#                  'display_phone': '(858) 283-8206',
#                  'distance': 12631.448973416174,
#                  'id': 'DyRjR955VS3paJZ2aHxm3g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NBr_OWuMTwU_CmMllx770w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9920 Pacific Heights Blvd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['9920 Pacific Heights Blvd',
#                                                   'San Diego, CA 92121'],
#                               'state': 'CA',
#                               'zip_code': '92121'},
#                  'name': 'Gravity Heights',
#                  'phone': '+18582838206',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 316,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gravity-heights-san-diego-2?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'modern-times-flavordome-san-diego-4',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'coffeeroasteries',
#                                  'title': 'Coffee Roasteries'}],
#                  'coordinates': {'latitude': 32.7413902282715,
#                                  'longitude': -117.129783630371},
#                  'display_phone': '(619) 269-5222',
#                  'distance': 5906.403703025261,
#                  'id': 'pU7YHHgCS8L2ShPPbPUCfw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/peBOLEZu5i7T3ye5sn0wgA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3000 Upas St',
#                               'address2': 'Ste 102',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['3000 Upas St',
#                                                   'Ste 102',
#                                                   'San Diego, CA 92104'],
#                               'state': 'CA',
#                               'zip_code': '92104'},
#                  'name': 'Modern Times Flavordome',
#                  'phone': '+16192695222',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 396,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/modern-times-flavordome-san-diego-4?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'border-x-brewing-san-diego-3',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'musicvenues',
#                                  'title': 'Music Venues'}],
#                  'coordinates': {'latitude': 32.69803, 'longitude': -117.13983},
#                  'display_phone': '(619) 501-0503',
#                  'distance': 10368.947485043387,
#                  'id': 'a51TfGQf7MKTsvJBsmnKzg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JeD0-ZwX4QPGIv3rJmKlbg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2181 Logan Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['2181 Logan Ave',
#                                                   'San Diego, CA 92113'],
#                               'state': 'CA',
#                               'zip_code': '92113'},
#                  'name': 'Border X Brewing',
#                  'phone': '+16195010503',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 295,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/border-x-brewing-san-diego-3?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'},
#                 {'alias': 'mikkeller-brewing-company-san-diego',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 32.89212, 'longitude': -117.14483},
#                  'display_phone': '(858) 381-3500',
#                  'distance': 11354.480317869264,
#                  'id': 'BeuZYd5D7tXDHr9faqpdWw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u8hpC1Tfc-5ss-Bs9VJv_A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9368 Cabot Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'San Diego',
#                               'country': 'US',
#                               'display_address': ['9368 Cabot Dr',
#                                                   'San Diego, CA 92126'],
#                               'state': 'CA',
#                               'zip_code': '92126'},
#                  'name': 'Mikkeller Brewing Company',
#                  'phone': '+18583813500',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 170,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mikkeller-brewing-company-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ'}],
#  'region': {'center': {'latitude': 32.790569394537286,
#                        'longitude': -117.15408325195312}},
#  'total': 825}

# %%
beer_businesses = []

for business in data['businesses']:
    name = business['name']
    coordinates = business['coordinates']
    rating = business['rating']
    review_count = business['review_count']
    beer_businesses.append({"Name": name, "Coordinates": coordinates, "Rating": rating, 
                            "Review_Count": review_count})

# %%
print(beer_businesses)
# Out:
# [{'Name': 'Societe Brewing Company', 'Coordinates': {'latitude': 32.833889, 'longitude': -117.146375}, 'Rating': 4.0, 'Review_Count': 607}, {'Name': 'AleSmith Brewing Company', 'Coordinates': {'latitude': 32.8873241, 'longitude': -117.1493986}, 'Rating': 4.5, 'Review_Count': 418}, {'Name': 'Pure Project', 'Coordinates': {'latitude': 32.8873375, 'longitude': -117.1555986}, 'Rating': 4.5, 'Review_Count': 661}, {'Name': 'The Original 40 Brewing', 'Coordinates': {'latitude': 32.74824, 'longitude': -117.12662}, 'Rating': 4.5, 'Review_Count': 58}, {'Name': 'Belching Beaver Brewery North Park', 'Coordinates': {'latitude': 32.7545205383526, 'longitude': -117.13002965232}, 'Rating': 4.5, 'Review_Count': 666}, {'Name': 'Black Market Brewing - San Diego', 'Coordinates': {'latitude': 32.76479, 'longitude': -117.06093}, 'Rating': 4.5, 'Review_Count': 39}, {'Name': 'Kilowatt Brewing', 'Coordinates': {'latitude': 32.8333702, 'longitude': -117.1560135}, 'Rating': 4.5, 'Review_Count': 193}, {'Name': 'Modern Times Beer', 'Coordinates': {'latitude': 32.754201, 'longitude': -117.206172011657}, 'Rating': 4.0, 'Review_Count': 625}, {'Name': 'Ballast Point Little Italy', 'Coordinates': {'latitude': 32.7275213525988, 'longitude': -117.169813710335}, 'Rating': 4.5, 'Review_Count': 1798}, {'Name': 'Half Door Brewing', 'Coordinates': {'latitude': 32.710263, 'longitude': -117.156272}, 'Rating': 4.5, 'Review_Count': 633}, {'Name': 'Green Flash Brewing Co', 'Coordinates': {'latitude': 32.9071098, 'longitude': -117.1777588}, 'Rating': 4.5, 'Review_Count': 998}, {'Name': 'Circle 9 Brewing', 'Coordinates': {'latitude': 32.8254665, 'longitude': -117.160549}, 'Rating': 4.5, 'Review_Count': 53}, {'Name': 'Bolt Brewery', 'Coordinates': {'latitude': 32.7719692578383, 'longitude': -117.020541742427}, 'Rating': 4.5, 'Review_Count': 238}, {'Name': 'Ketch Brewing', 'Coordinates': {'latitude': 32.81315, 'longitude': -117.15545}, 'Rating': 4.5, 'Review_Count': 27}, {'Name': 'Quantum Brewing', 'Coordinates': {'latitude': 32.83067, 'longitude': -117.13883}, 'Rating': 4.0, 'Review_Count': 192}, {'Name': 'Mission Brewery', 'Coordinates': {'latitude': 32.70715, 'longitude': -117.151592}, 'Rating': 4.5, 'Review_Count': 694}, {'Name': 'Gravity Heights', 'Coordinates': {'latitude': 32.90016, 'longitude': -117.19086}, 'Rating': 4.0, 'Review_Count': 316}, {'Name': 'Modern Times Flavordome', 'Coordinates': {'latitude': 32.7413902282715, 'longitude': -117.129783630371}, 'Rating': 4.0, 'Review_Count': 396}, {'Name': 'Border X Brewing', 'Coordinates': {'latitude': 32.69803, 'longitude': -117.13983}, 'Rating': 4.5, 'Review_Count': 295}, {'Name': 'Mikkeller Brewing Company', 'Coordinates': {'latitude': 32.89212, 'longitude': -117.14483}, 'Rating': 4.5, 'Review_Count': 170}]

# %%
beer_businesses_df = pd.DataFrame(beer_businesses)
beer_businesses_df
# Out:
#                                           Coordinates  \
# 0   {'latitude': 32.833889, 'longitude': -117.146375}
# 1   {'latitude': 32.8873241, 'longitude': -117.149...
# 2   {'latitude': 32.8873375, 'longitude': -117.155...
# 3     {'latitude': 32.74824, 'longitude': -117.12662}
# 4   {'latitude': 32.7545205383526, 'longitude': -1...
# 5     {'latitude': 32.76479, 'longitude': -117.06093}
# 6   {'latitude': 32.8333702, 'longitude': -117.156...
# 7   {'latitude': 32.754201, 'longitude': -117.2061...
# 8   {'latitude': 32.7275213525988, 'longitude': -1...
# 9   {'latitude': 32.710263, 'longitude': -117.156272}
# 10  {'latitude': 32.9071098, 'longitude': -117.177...
# 11  {'latitude': 32.8254665, 'longitude': -117.160...
# 12  {'latitude': 32.7719692578383, 'longitude': -1...
# 13    {'latitude': 32.81315, 'longitude': -117.15545}
# 14    {'latitude': 32.83067, 'longitude': -117.13883}
# 15   {'latitude': 32.70715, 'longitude': -117.151592}
# 16    {'latitude': 32.90016, 'longitude': -117.19086}
# 17  {'latitude': 32.7413902282715, 'longitude': -1...
# 18    {'latitude': 32.69803, 'longitude': -117.13983}
# 19    {'latitude': 32.89212, 'longitude': -117.14483}
#
#                                   Name  Rating  Review_Count
# 0              Societe Brewing Company     4.0           607
# 1             AleSmith Brewing Company     4.5           418
# 2                         Pure Project     4.5           661
# 3              The Original 40 Brewing     4.5            58
# 4   Belching Beaver Brewery North Park     4.5           666
# 5     Black Market Brewing - San Diego     4.5            39
# 6                     Kilowatt Brewing     4.5           193
# 7                    Modern Times Beer     4.0           625
# 8           Ballast Point Little Italy     4.5          1798
# 9                    Half Door Brewing     4.5           633
# 10              Green Flash Brewing Co     4.5           998
# 11                    Circle 9 Brewing     4.5            53
# 12                        Bolt Brewery     4.5           238
# 13                       Ketch Brewing     4.5            27
# 14                     Quantum Brewing     4.0           192
# 15                     Mission Brewery     4.5           694
# 16                     Gravity Heights     4.0           316
# 17             Modern Times Flavordome     4.0           396
# 18                    Border X Brewing     4.5           295
# 19           Mikkeller Brewing Company     4.5           170

# %%
coords = beer_businesses_df['Coordinates']
coords
# Out:
# 0     {'latitude': 32.833889, 'longitude': -117.146375}
# 1     {'latitude': 32.8873241, 'longitude': -117.149...
# 2     {'latitude': 32.8873375, 'longitude': -117.155...
# 3       {'latitude': 32.74824, 'longitude': -117.12662}
# 4     {'latitude': 32.7545205383526, 'longitude': -1...
# 5       {'latitude': 32.76479, 'longitude': -117.06093}
# 6     {'latitude': 32.8333702, 'longitude': -117.156...
# 7     {'latitude': 32.754201, 'longitude': -117.2061...
# 8     {'latitude': 32.7275213525988, 'longitude': -1...
# 9     {'latitude': 32.710263, 'longitude': -117.156272}
# 10    {'latitude': 32.9071098, 'longitude': -117.177...
# 11    {'latitude': 32.8254665, 'longitude': -117.160...
# 12    {'latitude': 32.7719692578383, 'longitude': -1...
# 13      {'latitude': 32.81315, 'longitude': -117.15545}
# 14      {'latitude': 32.83067, 'longitude': -117.13883}
# 15     {'latitude': 32.70715, 'longitude': -117.151592}
# 16      {'latitude': 32.90016, 'longitude': -117.19086}
# 17    {'latitude': 32.7413902282715, 'longitude': -1...
# 18      {'latitude': 32.69803, 'longitude': -117.13983}
# 19      {'latitude': 32.89212, 'longitude': -117.14483}
# Name: Coordinates, dtype: object

# %%
# aaa = pd.DataFrame(beer_businesses_df.Coordinates.str.split(',',1).tolist(),
#                                    columns = ['lat','long'])

lats = []
longs = []

for coord in coords:
    
    lat = coord['latitude']
    long = coord['longitude']
    lats.append(lat)
    longs.append(long)

print(lats)
# Out:
# [32.833889, 32.8873241, 32.8873375, 32.74824, 32.7545205383526, 32.76479, 32.8333702, 32.754201, 32.7275213525988, 32.710263, 32.9071098, 32.8254665, 32.7719692578383, 32.81315, 32.83067, 32.70715, 32.90016, 32.7413902282715, 32.69803, 32.89212]

# %%
beer_businesses_df['lat'] = lats
beer_businesses_df['long'] = longs

# %%
aa = beer_businesses_df.drop(['Coordinates'], axis=1)
aa
# Out:
#                                   Name  Rating  Review_Count        lat  \
# 0              Societe Brewing Company     4.0           607  32.833889
# 1             AleSmith Brewing Company     4.5           418  32.887324
# 2                         Pure Project     4.5           661  32.887338
# 3              The Original 40 Brewing     4.5            58  32.748240
# 4   Belching Beaver Brewery North Park     4.5           666  32.754521
# 5     Black Market Brewing - San Diego     4.5            39  32.764790
# 6                     Kilowatt Brewing     4.5           193  32.833370
# 7                    Modern Times Beer     4.0           625  32.754201
# 8           Ballast Point Little Italy     4.5          1798  32.727521
# 9                    Half Door Brewing     4.5           633  32.710263
# 10              Green Flash Brewing Co     4.5           998  32.907110
# 11                    Circle 9 Brewing     4.5            53  32.825466
# 12                        Bolt Brewery     4.5           238  32.771969
# 13                       Ketch Brewing     4.5            27  32.813150
# 14                     Quantum Brewing     4.0           192  32.830670
# 15                     Mission Brewery     4.5           694  32.707150
# 16                     Gravity Heights     4.0           316  32.900160
# 17             Modern Times Flavordome     4.0           396  32.741390
# 18                    Border X Brewing     4.5           295  32.698030
# 19           Mikkeller Brewing Company     4.5           170  32.892120
#
#           long
# 0  -117.146375
# 1  -117.149399
# 2  -117.155599
# 3  -117.126620
# 4  -117.130030
# 5  -117.060930
# 6  -117.156014
# 7  -117.206172
# 8  -117.169814
# 9  -117.156272
# 10 -117.177759
# 11 -117.160549
# 12 -117.020542
# 13 -117.155450
# 14 -117.138830
# 15 -117.151592
# 16 -117.190860
# 17 -117.129784
# 18 -117.139830
# 19 -117.144830
