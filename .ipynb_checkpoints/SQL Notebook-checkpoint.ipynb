# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from pandas.plotting import table

# %%
file = "data/csv/beer_winners_v2.csv"
aa = pd.read_csv(file)
aa
# Out:
#        Medal                            Beer Name  \
# 0       Gold                     Milwaukee’s Best
# 1       Gold                    County Seat Wheat
# 2       Gold                   Haywire Hefeweizen
# 3       Gold                      Raspberry Creek
# 4       Gold                       Stillwater Rye
# 5       Gold              Dude! Where’s My Vespa?
# 6       Gold                        Chateau Jiahu
# 7       Gold                    Crazy Jackass Ale
# 8       Gold                Countdown Honey Brown
# 9       Gold                           KinderPils
# 10      Gold                              Cardiff
# 11      Gold                           TPS Report
# 12      Gold                                W ‘10
# 13      Gold                      Celia Framboise
# 14      Gold                               Exit 4
# 15      Gold                      Rosso e Marrone
# 16      Gold                   Humidor Series IPA
# 17      Gold             Cereal Killer Barleywine
# ...
