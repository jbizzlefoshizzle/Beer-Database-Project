# %%
import requests
import json
import pandas as pd
from config import api_key
from config import token

# %%
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'term':'brewery','location':'San Diego California'}
url = "https://api.yelp.com/v3/businesses/search"
response = requests.get(url, headers=headers, params=params)
response_json = response.json()
response_json
# Out:
# {'businesses': [{'id': 'i0z5qviFAZe5knHFwSIYSg',
#    'alias': 'societe-brewing-company-san-diego',
#    'name': 'Societe Brewing Company',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3kMzqyZcEEt6d0hliKjbQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/societe-brewing-company-san-diego?adjust_creative=YMS3nsDc5AUcix9rnsV4oQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YMS3nsDc5AUcix9rnsV4oQ',
#    'review_count': 602,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.833889, 'longitude': -117.146375},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8262 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['8262 Clairemont Mesa Blvd', 'San Diego, CA 92111']},
# ...

# %%
response_json["businesses"][0]["rating"]
response_json["businesses"][0]["location"]["address1"]
response_json["businesses"][0]["price"]
response_json["businesses"][0]["review_count"]
response_json["businesses"][0]["name"]
response_json["businesses"][0]["coordinates"]["latitude"]
response_json["businesses"][0]["coordinates"]["longitude"]
# Out:
# -117.146375
